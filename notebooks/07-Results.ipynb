# %%
import json

# %%
with open('output/exp02/coco_instances_results.json') as f:
    results = json.load(f)


results
# Out:
# [{'image_id': 0,
#   'category_id': 23,
#   'bbox': [610.2559814453125,
#    1517.4876708984375,
#    80.9954833984375,
#    188.9346923828125],
#   'score': 0.9956560134887695,
#   'segmentation': {'size': [1763, 1168],
#    'counts': 'lfRQ11nf1<E7J9eYNCbe1S1L2N3N1N2N2N2N1O1O2O0O2N0010O001O01O00000000000000000O100O100O10O10O100000O10O01O100O01O001iLYNQaNh1n^1^Nl`Nb1T_1cNh`N]1X_1gNc`NZ1^_1iN^`NV1c_1mNY`NT1i_1nNR`NR1Q`1POk_No0W`1SOe_Nm0^`1SO^_Nn0e`1UOT_Nm0n`1YOh^Nh0\\a1^OZ^Nc0ia1Z23L8I9VLX]NDJj2Wd1I?@4L4M4L3L4L5K6I8Ffdci0'}},
#  {'image_id': 0,
#   'category_id': 33,
#   'bbox': [511.3466491699219,
#    311.63092041015625,
#    166.30960083007812,
#    168.55859375],
#   'score': 0.9935188889503479,
#   'segmentation': {'size': [1763, 1168],
# ...
